# %%
import dlt
from chess import source

# configure the pipeline: provide the destination and dataset name to which the data should go
pipeline = dlt.pipeline(
    pipeline_name="chess_pipeline",
    destination='postgres',
    dataset_name="chess_players_games_data",
)

# create the data source by providing a list of players and start/end month in YYYY/MM format
data = source(
    ["zundorn", "piwi100"],
    start_month="2024/01",
    end_month="2025/05"
)

# load the "players_games" and "players_profiles" out of all the possible resources
# https://dlthub.com/docs/general-usage/pipeline
info = pipeline.run(
        data.with_resources("players_games"), 
        write_disposition="merge",
        primary_key="uuid"
)

print(info)
# Out:
# archive period that will be re-processed: 2025/05
# Getting archive from https://api.chess.com/pub/player/piwi100/games/2025/05
# Pipeline chess_pipeline load step completed in 0.29 seconds
# 1 load package(s) were loaded to destination postgres and into dataset chess_players_games_data
# The postgres destination used postgresql://postgres:***@localhost:5432/sandbox location to store data
# Load package 1747071956.9653325 is LOADED and contains no failed jobs

# %%
from chess import players_archives, players_games

archives_for_player = list(players_archives(["piwi100"]))
games_for_player = list(players_games(["piwi100"], start_month="2024/01"))

print(archives_for_player)
print(games_for_player)
# Out:
# Getting archive from https://api.chess.com/pub/player/piwi100/games/2024/08
# Getting archive from https://api.chess.com/pub/player/piwi100/games/2024/09
# Getting archive from https://api.chess.com/pub/player/piwi100/games/2024/10
# Getting archive from https://api.chess.com/pub/player/piwi100/games/2024/11
# Getting archive from https://api.chess.com/pub/player/piwi100/games/2024/12
# Getting archive from https://api.chess.com/pub/player/piwi100/games/2025/01
# Getting archive from https://api.chess.com/pub/player/piwi100/games/2025/02
# Getting archive from https://api.chess.com/pub/player/piwi100/games/2025/03
# Getting archive from https://api.chess.com/pub/player/piwi100/games/2025/04
# Getting archive from https://api.chess.com/pub/player/piwi100/games/2025/05
# ['https://api.chess.com/pub/player/piwi100/games/2024/08', 'https://api.chess.com/pub/player/piwi100/games/2024/09', 'https://api.chess.com/pub/player/piwi100/games/2024/10', 'https://api.chess.com/pub/player/piwi100/games/2024/11', 'https://api.chess.com/pub/player/piwi100/games/2024/12', 'https://api.chess.com/pub/player/piwi100/games/2025/01', 'https://api.chess.com/pub/player/piwi100/games/2025/02', 'https://api.chess.com/pub/player/piwi100/games/2025/03', 'https://api.chess.com/pub/player/piwi100/games/2025/04', 'https://api.chess.com/pub/player/piwi100/games/2025/05']
# [{'url': 'https://www.chess.com/game/live/109017709068', 'pgn': '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2024.08.31"]\n[Round "-"]\n[White "Piwi100"]\n[Black "GoofyGoober_27"]\n[Result "1-0"]\n[CurrentPosition "3k3r/2p2p1p/p3bp2/bp6/5B2/1BP1PN2/PP3PPP/RN3RK1 w - -"]\n[Timezone "UTC"]\n[ECO "D00"]\n[ECOUrl "https://www.chess.com/openings/Queens-Pawn-Opening-Accelerated-London-System"]\n[UTCDate "2024.08.31"]\n[UTCTime "15:57:40"]\n[WhiteElo "581"]\n[BlackElo "398"]\n[TimeControl "600"]\n[Termination "Piwi100 won by resignation"]\n[StartTime "15:57:40"]\n[EndDate "2024.08.31"]\n[EndTime "16:04:34"]\n[Link "https://www.chess.com/game/live/109017709068"]\n\n1. d4 {[%clk 0:10:00]} 1... d5 {[%clk 0:09:55.6]} 2. Bf4 {[%clk 0:09:58.9]} 2... Nc6 {[%clk 0:09:50.5]} 3. e3 {[%clk 0:09:57.2]} 3... Nf6 {[%clk 0:09:37.3]} 4. Nf3 {[%clk 0:09:54.5]} 4... e5 {[%clk 0:09:33.9]} 5. dxe5 {[%clk 0:09:45.2]} 5... Bb4+ {[%clk 0:09:22]} 6. c3 {[%clk 0:09:39.8]} 6... Ba5 {[%clk 0:09:16.3]} 7. exf6 {[%clk 0:09:37.8]} 7... gxf6 {[%clk 0:09:14.2]} 8. Bb5 {[%clk 0:09:24.7]} 8... Bd7 {[%clk 0:09:08.9]} 9. Qxd5 {[%clk 0:09:09.1]} 9... a6 {[%clk 0:08:22.7]} 10. Ba4 {[%clk 0:09:03.3]} 10... b5 {[%clk 0:08:20.1]} 11. Bb3 {[%clk 0:08:46.4]} 11... Be6 {[%clk 0:07:45.3]} 12. Qxc6+ {[%clk 0:08:31.5]} 12... Bd7 {[%clk 0:07:39.6]} 13. Qe4+ {[%clk 0:08:01.9]} 13... Be6 {[%clk 0:07:14.7]} 14. O-O {[%clk 0:07:53.2]} 14... Qe7 {[%clk 0:06:53.5]} 15. Qxa8+ {[%clk 0:07:28.7]} 15... Qd8 {[%clk 0:06:42.3]} 16. Qxd8+ {[%clk 0:07:08.8]} 16... Kxd8 {[%clk 0:06:30.8]} 1-0\n', 'time_control': '600', 'end_time': 1725120274, 'rated': True, 'accuracies': {'white': 96.65, 'black': 74.22}, 'tcn': 'lBZJcD5Qmu!Tgv0KBK9zkszGKT2TfH6ZdJWOHyXHyrZSJQSZQCZSeg70C4074787', 'uuid': 'c2e144b0-67b1-11ef-9e98-b5317f01000f', 'initial_setup': 'rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1', 'fen': '3k3r/2p2p1p/p3bp2/bp6/5B2/1BP1PN2/PP3PPP/RN3RK1 w - -', 'time_class': 'rapid', 'rules': 'chess', 'white': {'rating': 581, 'result': 'win', '@id': 'https://api.chess.com/pub/player/piwi100', 'username': 'Piwi100', 'uuid': '67761568-678d-11ef-9795-abe330237493'}, 'black': {'rating': 398, 'result': 'resigned', '@id': 'https://api.chess.com/pub/player/goofygoober_27', 'username': 'GoofyGoober_27', 'uuid': '1e680b44-5e2b-11ef-901b-b96246f35774'}}, {'url': 'https://www.chess.com/game/live/109018643200', 'pgn': '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2024.08.31"]\n[Round "-"]\n[White "prakashdcse0815"]\n[Black "Piwi100"]\n[Result "1/2-1/2"]\n[CurrentPosition "7Q/8/8/3K4/4rk2/8/8/8 b - -"]\n[Timezone "UTC"]\n[ECO "A40"]\n[ECOUrl "https://www.chess.com/openings/Englund-Gambit-Declined-Reversed-French-Variation"]\n[UTCDate "2024.08.31"]\n[UTCTime "16:55:38"]\n[WhiteElo "599"]\n[BlackElo "587"]\n[TimeControl "600"]\n[Termination "Game drawn by repetition"]\n[StartTime "16:55:38"]\n[EndDate "2024.08.31"]\n[EndTime "17:14:59"]\n[Link "https://www.chess.com/game/live/109018643200"]\n\n1. e3 {[%clk 0:09:59.3]} 1... e5 {[%clk 0:09:58.5]} 2. d4 {[%clk 0:09:57.7]} 2... exd4 {[%clk 0:09:53.4]} 3. Qxd4 {[%clk 0:09:55.7]} 3... Nc6 {[%clk 0:09:51.6]} 4. Qe4+ {[%clk 0:09:50.1]} 4... Be7 {[%clk 0:09:45.5]} 5. Bb5 {[%clk 0:09:46.7]} 5... Nf6 {[%clk 0:09:31.2]} 6. Qc4 {[%clk 0:09:39.2]} 6... O-O {[%clk 0:09:05.3]} 7. Bxc6 {[%clk 0:09:35.4]} 7... bxc6 {[%clk 0:08:59.7]} 8. e4 {[%clk 0:09:32]} 8... d5 {[%clk 0:08:51.2]} 9. exd5 {[%clk 0:09:25.2]} 9... cxd5 {[%clk 0:08:45.2]} 10. Qc6 {[%clk 0:09:18.2]} 10... Rb8 {[%clk 0:08:20.1]} 11. Bg5 {[%clk 0:09:00.5]} 11... Bb7 {[%clk 0:08:07.2]} 12. Qb5 {[%clk 0:08:41.8]} 12... c6 {[%clk 0:07:59.9]} 13. Qe2 {[%clk 0:08:33.4]} 13... Ba6 {[%clk 0:07:37.7]} 14. Qxa6 {[%clk 0:08:29.1]} 14... h6 {[%clk 0:07:05.7]} 15. Bxf6 {[%clk 0:08:24.1]} 15... Bxf6 {[%clk 0:07:03.3]} 16. c3 {[%clk 0:08:20.4]} 16... Re8+ {[%clk 0:06:49.3]} 17. Ne2 {[%clk 0:08:17.1]} 17... Qe7 {[%clk 0:06:42.3]} 18. Nd2 {[%clk 0:08:01.2]} 18... Rb6 {[%clk 0:06:23.6]} 19. Qd3 {[%clk 0:07:46.8]} 19... R ...

# %%
import base64
import zlib
import json

# Paste your encoded state here
encoded = """"""

# Decode from base64
compressed = base64.b64decode(encoded)

# Decompress using zlib
decompressed = zlib.decompress(compressed)

# Parse JSON
state = json.loads(decompressed)

# Print the result
import pprint
pprint.pprint(state)
# Out:
# {'_state_engine_version': 4,
#  '_state_version': 1,
#  '_version_hash': 'cbQcLasRTOwQjjk6A9TBaOrQh+n+/RXuJ6ddO5IAETk=',
#  'dataset_name': 'chess_players_games_data',
#  'default_schema_name': 'chess',
#  'destination_name': None,
#  'destination_type': 'dlt.destinations.postgres',
#  'pipeline_name': 'chess_pipeline',
#  'schema_names': ['chess'],
#  'sources': {'chess': {'resources': {'players_games': {'archives': ['https://api.chess.com/pub/player/piwi100/games/2024/08',
#                                                                     'https://api.chess.com/pub/player/piwi100/games/2024/09',
#                                                                     'https://api.chess.com/pub/player/piwi100/games/2024/10',
#                                                                     'https://api.chess.com/pub/player/piwi100/games/2024/11',
#                                                                     'https://api.chess.com/pub/player/piwi100/games/2024/12',
#                                                                     'https://api.chess.com/pub/player/piwi100/games/2025/01',
#                                                                     'https://api.chess.com/pub/player/piwi100/games/2025/02',
#                                                                     'https://api.chess.com/pub/player/piwi100/games/2025/03',
#                                                                     'https://api.chess.com/pub/player/piwi100/games/2025/04',
#                                                                     'https://api.chess.com/pub/player/piwi100/games/2025/05']}}}}}
